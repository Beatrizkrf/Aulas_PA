# %% [markdown]
# <a href="https://colab.research.google.com/github/Beatrizkrf/Aulas_PA/blob/main/Fluxograma_13_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Exercico 1:**

# %%
peca = int(input("Digite o valo da peca:"))
quant = int(input("Digite o numero de peca:"))
vt = quant * peca
vt = (print("O valor total de peça é: ", vt))
# Out:
# Digite o valo da peca:3
# Digite o numero de peca:4
# O valor total de peça é:  12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Exercico 2:**

# %%
quant_min = int(input("Digite a quantidade minima de peças:"))
quant_max = int(input("Digite a quantidade máxima:"))
estoquem = float(quant_min + quant_max)/2
estoquem = print("O estoque médio de peças é:", estoquem)
# Out:
# Digite a quantidade minima de peças:2
# Digite a quantidade máxima:10
# O estoque médio de peças é: 6.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Exercício 3:**

# %%
valr = int(input("Digite o valor desejado:"))
dolar = 4.5
convertr = float(valr/dolar)
convertr = print("Seu dinheiro convertido é de:R$", convertr)
# Out:
# Digite o valor desejado:100
# Seu dinheiro convertido é de:R$ 22.22222222222222

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Exercício 4:**

# %%
a = float(input('Digite o número:'))
b = float(input('Digite o número:'))
c = float(input('Digite o número:'))
d = float(input('Digite o número:'))
a1 = float(a*a)
b1 = float (b*b)
c1 = float (c*c)
d1 = float (d*d)
alfabeto = float(a1+b1+c1+d1)
alfabeto= print('O resultado da equação é:',alfabeto)
# Out:
# Digite o número:2
# Digite o número:4
# Digite o número:5
# Digite o número:6
# O resultado da equação é: 81.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Exercício 5:**

# %%
preunit = float(input("Digite o preço unitário da peça:"))
vendida = int(input("Digite a quantidade que foi vendida:"))
comiss = float(preunit*vendida)
vend = float (comiss*0.5)
comissa = float(vend/10)
comissa = print("A comissão recebida com o acréscimo de 5% será:", comissa)
comiss = print("O valor de vendas será", comiss)
# Out:
# Digite o preço unitário da peça:2.5
# Digite a quantidade que foi vendida:200
# A comissão recebida com o acréscimo de 5% será: 25.0
# O valor de vendas será 500.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Exercício 6:**

# %%
fabrica = int(input('Custo de Fábrica:'))
imposto = float (fabrica*0.45)
cons= float (imposto + fabrica)
distri= float(cons*0.28)
valor= float(distri + cons)
valor= print('O preço para o consumidor será de:',valor)
# Out:
# Custo de Fábrica:25000
# O preço para o consumidor será de: 46400.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Exercício 7:**

# %%
hr = float(input('Digite a hora:'))
min = float(input('Digite os minutos:'))
n1 = float(min/60)
h1 = float(hr+n1)
h1 = print('Conversão para segundos:',h1)
# Out:
# Digite a hora:1
# Digite os minutos:0
# Conversão para segundos: 1.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Exercício 8:**

# %%
hrs = float(input('digite o valor de horas trabalhadas:'))
gan = int (input('digite o valor ganhado por horas:'))
sal = float(hrs*gan)
extra = float(sal*0.70)
extra = float(sal+extra)
extra = print('O valor ganhado com a hora extra é de',extra)
# Out:
# digite o valor de horas trabalhadas:15.75
# digite o valor ganhado por horas:25
# O valor ganhado com a hora extra é de 669.375

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Exercíco 9:**

# %%
km = float(input('Quilometros percorridos:' ))
gasol = float(input('Litros de gasolina consumidos por km:'))
preco = float (input('O preço da gasolina é de:'))
c1 = float(km/gasol)
ida = float(c1 * preco)
vol = float(ida * 2)
ida = print('O preço médio de gasolina na ida é:', ida)
vol = print('O preço médio de gasolina na volta é:', vol)
# Out:
# Quilometros percorridos:450
# Litros de gasolina consumidos por km:10
# O preço da gasolina é de:4.5
# O preço médio de gasolina na ida é: 202.5
# O preço médio de gasolina na volta é: 405.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Exercício 10:**

# %%
#Coletando os valores para as variáveis de entrada
km =float(input('Quilometros a percorrer:'))
h = float(input('Horas gastas:'))
m = float (input('Minutos gastos:'))
#Processamento
m1= float(m/60)
h1= float (m1 + h)
vm = float (km/h1)
resultado =round(vm,2)
#Execução final:
resultado = print('A velocidade média do carro é de:',resultado, 'km')
# Out:
# Quilometros a percorrer:150
# Horas gastas:1
# Minutos gastos:13
# A velocidade média do carro é de: 123.29 km

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Explicação do professor (exercício 10):

# %%
km =float(input('Quilometros a percorrer:'))
h = float(input('Horas gastas:'))
m = float (input('Minutos gastos:'))
m1= float(m/60)
# Out:
# Quilometros a percorrer:150
# Horas gastas:1
# Minutos gastos:13

# %%
m1
# Out:
# 0.21666666666666667

# %%
m1= float(m/60)
h1= float (m1 + h)
vm = float(km/h1)

# %%
vm
# Out:
# 123.2876712328767

# %% [markdown]
# teste arredondamento:

# %%
 numero = 3.5
 resultado = round(numero)
 print(resultado)  # Saída: 3
# Out:
# 4
